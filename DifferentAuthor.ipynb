# %%
import numpy as np
import matplotlib.pyplot as plot

# %%
import numpy as np
import matplotlib.pyplot as plt

# 生成数据
x1 = [931,184,295,72,114]
x2 = [200, 771, 109, 139, 167]
x3 = [247, 97, 1624, 71, 68]
x4 = [53, 109, 148, 1451, 185]
x5 = [55, 76, 87, 208, 2208]
y = ['first','second', '30%', '60%','last']

plt.figure(figsize = (20,20))

# 子图 1
plt.subplot(2, 3, 1)
plt.pie(x1, labels = y, autopct='%.2f%%', startangle = 90, colors = ["orange","green","pink", "grey","olive"])
# 子图 2
plt.subplot(2, 3, 2)
plt.pie(x2, labels = y, autopct='%.2f%%', startangle = 90, colors = ["orange","green","pink", "grey","olive"])
# 子图 3
plt.subplot(2, 3, 3)
plt.pie(x3, labels = y, autopct='%.2f%%', startangle = 90, colors = ["orange","green","pink", "grey","olive"])
# 子图 4
plt.subplot(2, 3, 4)
plt.pie(x4, labels = y, autopct='%.2f%%', startangle = 90, colors = ["orange","green","pink", "grey","olive"])
plt.subplot(2, 3, 5)
plt.pie(x5, labels = y, autopct='%.2f%%', startangle = 90, colors = ["orange","green","pink", "grey","olive"])
plt.legend()
plt.show()
